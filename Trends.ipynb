# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style 
import os

# %%
it_assets = pd.read_csv('EGYPT IT Asset.csv')
it_assets.head()
# Out:
#                 Unnamed: 0              EGYPT         Unnamed: 2  \
# 0                      NaN  Apr '20 ~ Mar '21  Apr '21 ~ Mar '22
# 1                   Mobile                  0                  0
# 2  Network Providers - SIM              4,399              1,104
# 3                   Laptop             35,283              7,040
# 4                Computers              1,762                256
#
#           Unnamed: 3
# 0  Apr '22 ~ Mar '23
# 1                  0
# 2                489
# 3                543
# 4                176

# %%
it_assets.columns=['Assets Type','Apr 20 - Mar 21','Apr 21 - Mar 22','Apr 22 - Mar 23']

# %%
it_assets
# Out:
#                      Assets Type    Apr 20 - Mar 21    Apr 21 - Mar 22  \
# 0                            NaN  Apr '20 ~ Mar '21  Apr '21 ~ Mar '22
# 1                         Mobile                  0                  0
# 2        Network Providers - SIM              4,399              1,104
# 3                         Laptop             35,283              7,040
# 4                      Computers              1,762                256
# 5   Network Providers - Internet              3,515              1,139
# 6                             TV              1,587                  0
# 7                     Projectors                  0                  0
# 8                         Camera                  0                  0
# 9               Printer, Copiers              5,922              2,309
# 10          Computer Accessories              1,512                798
# 11      Conference Communicators                  0                  0
# ...

# %%
it_assets = it_assets.drop(it_assets.index[0])

# %%
it_assets
# Out:
#                      Assets Type Apr 20 - Mar 21 Apr 21 - Mar 22  \
# 1                         Mobile               0               0
# 2        Network Providers - SIM           4,399           1,104
# 3                         Laptop          35,283           7,040
# 4                      Computers           1,762             256
# 5   Network Providers - Internet           3,515           1,139
# 6                             TV           1,587               0
# 7                     Projectors               0               0
# 8                         Camera               0               0
# 9               Printer, Copiers           5,922           2,309
# 10          Computer Accessories           1,512             798
# 11      Conference Communicators               0               0
# 12                      Speakers             778               0
# 13           Annual IT Main Cost           1,291           1,035
#
#    Apr 22 - Mar 23
# 1                0
# ...

# %%
it_assets.head()
# Out:
#                     Assets Type Apr 20 - Mar 21 Apr 21 - Mar 22  \
# 1                        Mobile               0               0
# 2       Network Providers - SIM           4,399           1,104
# 3                        Laptop          35,283           7,040
# 4                     Computers           1,762             256
# 5  Network Providers - Internet           3,515           1,139
#
#   Apr 22 - Mar 23
# 1               0
# 2             489
# 3             543
# 4             176
# 5           1,289

# %%
assettype = it_assets['Assets Type']
year1 = it_assets['Apr 20 - Mar 21']
year2 = it_assets['Apr 21 - Mar 22']
year3 = it_assets['Apr 22 - Mar 23']

# %%
fig = plt.figure(figsize=(15,10))
plt.barh(assettype, year1)
plt.xlabel('ASSETS TYPES')
plt.ylabel('YEAR')
plt.title('Egypt It Asset (eg)')
plt.show()
