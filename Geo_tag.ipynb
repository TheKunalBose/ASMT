# %%
from geopy.geocoders import ArcGIS

# %%
pip install geopy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 kB 1.4 MB/s eta 0:00:001.5 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
nom = ArcGIS()

# %%
s = nom.geocode('Bangalore')

# %%
s.latitude
# Out:
# 12.96614

# %%
s.longitude
# Out:
# 77.58694

# %%
pip install folium
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.3/102.3 kB 3.6 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/48/73/df07644e8fa1127a7985db70cf1d07123004e2dd7a3cf33e8b83297a775b/numpy-1.25.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 8.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
map = folium.Map(location=[12.96614,77.58694])

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map.add_child(folium.Marker(location=[12.96614,77.58694],popup='tkd',icon=folium.Icon(color='orange')))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd

# %%
pip install pandas
# Out:
#   Cell In[18], line 1
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %%
pip3 install pandas
# Out:
#   Cell In[19], line 1
#     pip3 install pandas
#          ^
# SyntaxError: invalid syntax

# %%
geo_cod=pd.read_csv('Geo_Map_Cod.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 geo_cod=pd.read_csv('Geo_Map_Cod.txt')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
pwd
# Out:
# '/Users/kunal/Documents/My Soft /Python/TruKKer '

# %%
geo_cod = pd.read_csv('Geo_map.csv')

# %%
geo_cod
# Out:
#    Trukker Geo map Expressions   Unnamed: 1      Unnamed: 2  \
# 0                         Sno.     Country            City
# 1                           NaN         NaN             NaN
# 2                             1      India        Bangalore
# 3                             2         UAE           Dubai
# 4                             3         UAE  Ras Al Khaima
# 5                             4         UAE           Dubai
# 6                             5         UAE     Abhu Dhabi
# 7                             6         UAE     Abhu Dhabi
# 8                             7     Bahrain          Sitra
# 9                             8      Turkey       Istanbul
# 10                            9        Oman         Muscat
# 11                           10        Oman          Sohar
# 12                           11        Oman         Salalah
# 13                           12         KSA          Jeddah
# 14                           13         KSA           Yanbu
# ...

# %%
geo_asset = pd.read_csv('Global Assets Cost - 2020~2023.csv')

# %%
geo_asset
# Out:
#    \nGLOBAL ADMIN COST CONSOLIDATION  \
# 0                                NaN
# 1                                NaN
# 2                          IT Assets
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                               NaN
# 11                               NaN
# 12                               NaN
# 13                               NaN
# 14                               NaN
# 15                               NaN
# 16                               NaN
# 17                          Services
# 18                               NaN
# 19                               NaN
# 20                               NaN
# 21                               NaN
# 22                               NaN
# 23                               NaN
# ...

# %%
geo_cod.columns=['Sno.','Country','City','Locations']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 geo_cod.columns=['Sno.','Country','City','Locations']
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:6002, in NDFrame.__setattr__(self, name, value)
#    6000 try:
#    6001     object.__getattribute__(self, name)
# -> 6002     return object.__setattr__(self, name, value)
#    6003 except AttributeError:
#    6004     pass
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:730, in NDFrame._set_axis(self, axis, labels)
#     725 """
# ...

# %%
geo_cod.columns=['S.no','Country','City','Locations','Latitude','Longitude']

# %%
geo_cod
# Out:
#      S.no     Country            City               Locations  \
# 0   Sno.     Country            City               Locations
# 1     NaN         NaN             NaN                     NaN
# 2       1      India        Bangalore               Bangalore
# 3       2         UAE           Dubai  JLT Head Office Dubai
# 4       3         UAE  Ras Al Khaima                     Rak
# 5       4         UAE           Dubai                  Aweer
# 6       5         UAE     Abhu Dhabi                  Maffraq
# 7       6         UAE     Abhu Dhabi               Adnoc 893
# 8       7     Bahrain          Sitra                   Sitra
# 9       8      Turkey       Istanbul                Istanbul
# 10      9        Oman         Muscat                  Muscat
# 11     10        Oman          Sohar                   Sohar
# 12     11        Oman         Salalah                Salalah
# 13     12         KSA          Jeddah                  Jeddah
# ...

# %%
geo_cod = geo_cod.drop(geo_cod.index[0])

# %%
geo_cod = geo_cod.drop(geo_cod.index[1])

# %%
geo_cod = geo_cod.drop(geo_cod.index[0])

# %%
geo_cod
# Out:
#    S.no     Country            City               Locations  \
# 1   NaN         NaN             NaN                     NaN
# 3     2         UAE           Dubai  JLT Head Office Dubai
# 4     3         UAE  Ras Al Khaima                     Rak
# 5     4         UAE           Dubai                  Aweer
# 6     5         UAE     Abhu Dhabi                  Maffraq
# 7     6         UAE     Abhu Dhabi               Adnoc 893
# 8     7     Bahrain          Sitra                   Sitra
# 9     8      Turkey       Istanbul                Istanbul
# 10    9        Oman         Muscat                  Muscat
# 11   10        Oman          Sohar                   Sohar
# 12   11        Oman         Salalah                Salalah
# 13   12         KSA          Jeddah                  Jeddah
# 14   13         KSA           Yanbu                   Yanbu
# 15   14         KSA          Dammam                  Dammam
# 16   15         KSA          Riyadh                 Riyadh
# ...

# %%
geo_cod
# Out:
#    S.no     Country            City               Locations  \
# 3     2         UAE           Dubai  JLT Head Office Dubai
# 4     3         UAE  Ras Al Khaima                     Rak
# 5     4         UAE           Dubai                  Aweer
# 6     5         UAE     Abhu Dhabi                  Maffraq
# 7     6         UAE     Abhu Dhabi               Adnoc 893
# 8     7     Bahrain          Sitra                   Sitra
# 9     8      Turkey       Istanbul                Istanbul
# 10    9        Oman         Muscat                  Muscat
# 11   10        Oman          Sohar                   Sohar
# 12   11        Oman         Salalah                Salalah
# 13   12         KSA          Jeddah                  Jeddah
# 14   13         KSA           Yanbu                   Yanbu
# 15   14         KSA          Dammam                  Dammam
# 16   15         KSA          Riyadh                 Riyadh
# 17   16         KSA         Jubail                  Jubail
# ...

# %%
geo_cod.set_index('S.no',inplace=True)

# %%
geo_cod
# Out:
#          Country            City               Locations             Latitude  \
# S.no
# 2            UAE           Dubai  JLT Head Office Dubai       25° 4' 3.612" N
# 3            UAE  Ras Al Khaima                     Rak    25° 48' 2.4984'' N
# 4            UAE           Dubai                  Aweer      25° 10' 32.52" N
# 5            UAE     Abhu Dhabi                  Maffraq    24° 28' 0.0012" N
# 6            UAE     Abhu Dhabi               Adnoc 893   24° 27' 41.5260'' N
# 7        Bahrain          Sitra                   Sitra      26° 08' 60.00" N
# 8         Turkey       Istanbul                Istanbul    41° 0' 54.4932'' N
# 9           Oman         Muscat                  Muscat   23° 36' 51.5808'' N
# 10          Oman          Sohar                   Sohar      24° 21' 59.99" N
# 11          Oman         Salalah                Salalah      17° 00' 54.18" N
# 12           KSA          Jeddah                  Jeddah  21° 29' 33.0000'' N
# ...

# %%
geo_cod
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 geo_cod
#
# NameError: name 'geo_cod' is not defined

# %%
import folium

# Create a map
map = folium.Map(location=[latitude, longitude], zoom_start=13)

# Create HTML code for the custom popup
popup_html = "<h3>Custom Popup</h3><p>This is a custom popup.</p>"

# Create a marker with the custom popup
marker = folium.Marker(location=[marker_latitude, marker_longitude], popup=popup_html)

# Add the marker to the map
marker.add_to(map)

# Display the map
map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import folium
#       3 # Create a map
# ----> 4 map = folium.Map(location=[latitude, longitude], zoom_start=13)
#       6 # Create HTML code for the custom popup
#       7 popup_html = "<h3>Custom Popup</h3><p>This is a custom popup.</p>"
#
# NameError: name 'latitude' is not defined

# %%
map.add_child(folium.Marker(location=[12.96614,77.58694],popup='tkd',icon=folium.Icon(color='orange')))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
